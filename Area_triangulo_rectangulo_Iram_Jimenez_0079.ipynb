# %% [markdown]
# <a href="https://colab.research.google.com/github/IramJimenez128/EPPL-Area-triangulo-rectangulo-mis-imagenes/blob/main/Area_triangulo_rectangulo_Iram_Jimenez_0079.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Iram Jimenez NL 28 Fecha 25/Mar/2026
# ## Calcula el area de un triangulo rectangulo
# ![Logo de Markdown](https://raw.githubusercontent.com/IramJimenez128/EPPL-Area-triangulo-rectangulo-mis-imagenes/refs/heads/main/Area%20triangulo%20rectangulo.png)
#
# ---
# ## Formula para calcular traingulo rectangulo
# $A= b*h/2$
#
# ---
#
# ## Datos de entrada
# $b$ ? $h$ ?
#
# ---
#
# ## Diagrama de flujo de Lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/IramJimenez128/EPPL-Area-triangulo-rectangulo-mis-imagenes/refs/heads/main/DF%20Area%20triangulo.png)

# %%
#Calcular area de un triangulo rectangulo
# Variables b, h, a
# Formulas A= b*h/2
# Capturar el valor de b
# Capturar el valor de h
print("Calcular area de un triangulo rectangulo")
b=float(input("Ingrese el valor de la base: "))
h=float(input("Ingrese el valor de la altura: "))
a=b*h/2
print("El area del triangulo es: ", a)
print("Iram Jimenez NL = 28")
# Out:
# Calcular area de un triangulo rectangulo
# Ingrese el valor de la base: 6
# Ingrese el valor de la altura: 5
# El area del triangulo es:  15.0
# Iram Jimenez NL = 28

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo en tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/IramJimenez128/EPPL-Area-triangulo-rectangulo-mis-imagenes/refs/heads/main/tldraw%20area%20triangulo.png)
